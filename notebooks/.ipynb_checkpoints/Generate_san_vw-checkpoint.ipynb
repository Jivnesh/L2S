# %% [markdown]
# ### Generate_san_vw
# For train,test,dev files

# %%
import fasttext
model = fasttext.load_model("../../fastText/result/cc.sanskrit.50.bin")
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
indeclinable = ['ind','prep','interj','prep','conj','part','abs','ca abs']
case_list = ['nom','voc','acc','i','dat','abl','g','loc']
gender_list = ['n','f','m','*']
person_list = ['1','2','3']
no_list = ['du','sg','pl']
pops = [' ac',' ps']

# %%
# Get all the tags in hash list
import re 
hash = {}
tag_file_name = '../data/san_tags'
# input_file_name = './sanskrit_treebank/ud_pos_ner_dp_train_san'
files = ['ud_pos_ner_dp_dev_san','ud_pos_ner_dp_train_san','ud_pos_ner_dp_test_san']

def readtags():
    for line in open(tag_file_name).readlines():
        hash[line.split()[0]] = int(line.strip().split()[1])
c = 1
readtags()
for input_file_name in files:
    data = open('../data/'+input_file_name).readlines()
    writer = open('../models/Dep_san_temp/'+input_file_name+'.vw','w')
    for line in data:
    #     print('Line',line)
        if line == '\n':
            writer.write('\n')
            continue
        splits = line.strip().split('\t')

        # This replace can be removed.
        strw = "|w %s"%splits[1].replace(":","COL");
#         strp = "|p %s"%splits[2].replace(":","COL");
        
#         #############################################
#         # Variation : 0(a)
#         temp = re.sub("([\(\[]).*?([\)\]])", "\g<1>\g<2>", splits[2]).replace('[] ','').strip(' []')
#         strp = "|p %s"%temp.replace(":","COL");
        
#         #############################################
#         # Variation : I
#         # Variation : II added c=c.replace(' ac','').replace(' ps','')
#         temp = re.sub("([\(\[]).*?([\)\]])", "\g<1>\g<2>", splits[2]).replace('[] ','').strip(' []')
#         temp = temp.split('.')
#         if temp[-1] == '':
#             temp.pop(-1)
#         if len(temp) == 3: 
#             var = 'case=%s no=%s gender=%s'%(temp[0].strip().replace(' ac','').replace(' ps',''),temp[1].strip(),temp[2].strip())
#         elif len(temp) == 1:
#             var = 'case=%s'%(temp[0].strip().replace(' ac','').replace(' ps',''))
#         elif len(temp) == 2:
#             c=temp[0].strip()+ ' '+temp[1].strip()
#             c=c.replace(' ac','').replace(' ps','')
#             var = 'case=%s'%(c)
#         elif len(temp) == 4:
#             c=temp[0].strip()+ ' '+temp[1].strip()
#             c=c.replace(' ac','').replace(' ps','')
#             var = 'case=%s no=%s gender=%s'%(c,temp[2].strip(),temp[3].strip())
#         elif len(temp) == 5:
#             c=temp[0].strip()+ ' '+temp[1].strip() + ' '+temp[2].strip()
#             c=c.replace(' ac','').replace(' ps','')
#             var = 'case=%s no=%s gender=%s'%(c,temp[3].strip(),temp[4].strip())
#         else:
#             print('Handle me!')
#             print(temp)
#         strp = "|pos %s"%var;
        #################################################
#         # Variation:III
#         temp = re.sub("([\(\[]).*?([\)\]])", "\g<1>\g<2>", splits[2]).replace('[] ','').strip(' []')
#         temp = temp.split('.')
#         if temp[-1] == '':
#             temp.pop(-1)
#         # Remove active passive
#         case=''
#         no=''
#         person=''
#         gender=''
#         tense=''
#         
#         for a,b in enumerate(temp):
#             if b in pops:
#                 temp.pop(a)
#         # Get gender
#         for a,b in enumerate(temp):
#             if b.strip() in gender_list:
#                 gender = b.strip()
#                 temp.pop(a)
#         # Get case
#         for a,b in enumerate(temp):
#             if b.strip() in case_list:
#                 case = b.strip()
#                 temp.pop(a)
#         # Get person
#         for a,b in enumerate(temp):
#             if b.strip() in person_list:
#                 person = b.strip()
#                 temp.pop(a)
#         # Get no
#         for a,b in enumerate(temp):
#             if b.strip() in no_list:
#                 no = b.strip()
#                 temp.pop(a)
#         # Get Tense
#         for b in temp:
#             tense=tense+ ' '+b.strip()
#         tense=tense.strip()
#         var=''
#         if case:
#             t = 'case=%s '%case
#             var=var+t
#         if gender:
#             t = 'gender=%s '%gender
#             var=var+t
#         if tense:
#             t = 'tense=%s '%tense
#             var=var+t
#         if no:
#             t = 'no=%s '%no
#             var=var+t
#         if person:
#             t = 'case=%s '%person
#             var=var+t
#         print(var)

        ##################################################################################
#         # Variation IV
#         temp = re.sub("([\(\[]).*?([\)\]])", "\g<1>\g<2>", splits[2]).replace('[] ','').strip(' []')
#         temp = temp.split('.')
#         if temp[-1] == '':
#             temp.pop(-1)
#         # Remove active passive
#         case=''
#         no=''
#         person=''
#         gender=''
#         tense=''
#         coarse=''
#         for a,b in enumerate(temp):
#             if b in pops:
#                 temp.pop(a)
#         # Get gender
#         for a,b in enumerate(temp):
#             if b.strip() in gender_list:
#                 gender = b.strip()
#                 temp.pop(a)
#         # Get case
#         for a,b in enumerate(temp):
#             if b.strip() in case_list:
#                 case = b.strip()
#                 temp.pop(a)
#         if case!= '':
#             coarse ='Noun'
#         # Get person
#         for a,b in enumerate(temp):
#             if b.strip() in person_list:
#                 person = b.strip()
#                 temp.pop(a)
#         # Get no
#         for a,b in enumerate(temp):
#             if b.strip() in no_list:
#                 no = b.strip()
#                 temp.pop(a)
#         # Get Tense
        
#         for b in temp:
#             tense=tense+ ' '+b.strip()
#         tense=tense.strip()
#         if tense == 'adv':
#             coarse = 'adv'
#         for ind in indeclinable:
#             if tense == ind:
#                 coarse = 'Ind'
#         if tense!='' and coarse=='':
#             if no=='':
#                 coarse = 'IV'
#             elif person !='' and no!='':
#                 coarse = 'FV'
#         var=''
#         if case:
#             t = 'case=%s '%case
#             var=var+t
#         if gender:
#             t = 'gender=%s '%gender
#             var=var+t
#         if tense:
#             t = 'tense=%s '%tense
#             var=var+t
#         if no:
#             t = 'no=%s '%no
#             var=var+t
#         if person:
#             t = 'case=%s '%person
#             var=var+t
#         if coarse:
#             t = 'coarse=%s '%coarse
#             var=var+t
#         strp = "|pos %s"%var.strip();
#         print(var)
#         word = model.get_word_vector(splits[1]);
#         feature = ''
#         i=0
#         for v in word[:20]:
#             feature = feature+' '+str(v)
# #             feature = feature+' '+'F'+str(i)+':'+str(v)

#             i=i+1
#         embedding = "|FastText%s"%feature;
#         strq = "|FASTTEXT T0:%s U1:%s"%(word[1],word[1]);
        tag = splits[-1]
        if tag not in hash:
            hash[tag] = c
            c+=1

        #writer.write('%s 1.0  %s:%s%s %s\n'%((int(splits[7])+1) + (hash[tag]<<8), int(splits[7]),tag,strw, strp))
        # Writing in order
        # head, tag_integer mapping, head, tag, word, pos
        writer.write('%s %s %s:%s%s %s\n' % (int(splits[4]), hash[tag], int(splits[4]), tag, strw, strp))

    writer.close()
print('Value of out of voc tag ',c)
print('successful')
# Out:
# case=nom gender=* no=sg coarse=Noun
# case=i gender=f no=pl coarse=Noun
# tense=prep coarse=Ind
# case=acc gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=pp coarse=IV
# case=loc gender=m no=sg coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=pp no=sg
# case=nom gender=m no=sg coarse=Noun
# case=g gender=m no=sg coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# tense=conj coarse=Ind
# case=acc gender=f no=sg coarse=Noun
# tense=conj coarse=Ind
# case=acc gender=f no=sg coarse=Noun
# tense=pft no=sg case=3 coarse=FV
# case=loc gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# tense=adv coarse=adv
# tense=pr no=sg case=1 coarse=FV
# case=acc gender=f no=sg coarse=Noun
# tense=ppr coarse=IV
# case=loc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=pft no=sg case=3 coarse=FV
# case=nom gender=f no=sg coarse=Noun
# case=g gender=f no=pl coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=g gender=n no=pl coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=pft no=sg case=3 coarse=FV
# case=loc gender=n no=pl coarse=Noun
# case=loc gender=n no=pl coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=adv coarse=adv
# tense=ppa coarse=IV
# case=loc gender=n no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=* no=pl coarse=Noun
# case=g gender=n no=sg coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# case=i gender=m no=sg coarse=Noun
# tense=ca inf coarse=IV
# tense=impft no=sg case=3 coarse=FV
# case=loc gender=n no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=prep coarse=Ind
# case=g gender=* no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# tense=part coarse=Ind
# tense=abs coarse=Ind
# case=acc gender=m no=sg coarse=Noun
# tense=prep coarse=Ind
# tense=pp coarse=IV
# tense=part coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# gender=f tense=inst no=pl
# tense=conj coarse=Ind
# case=acc gender=f no=sg coarse=Noun
# tense=conj coarse=Ind
# case=acc gender=m no=sg coarse=Noun
# case=g gender=m no=pl coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=pft no=sg case=3 coarse=FV
# case=nom gender=* no=pl coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# tense=opt no=pl case=2 coarse=FV
# case=g gender=* no=sg coarse=Noun
# case=dat gender=n no=du coarse=Noun
# case=loc gender=m no=du coarse=Noun
# tense=abs coarse=Ind
# tense=adv coarse=adv
# tense=adv coarse=adv
# case=acc gender=f no=sg coarse=Noun
# tense=impft md no=sg case=1 coarse=FV
# tense=conj coarse=Ind
# case=loc gender=n no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# tense=impft no=sg case=3 coarse=FV
# case=loc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=abs coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=pp coarse=IV
# tense=adv coarse=adv
# case=acc gender=n no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# tense=inf coarse=IV
# tense=part coarse=Ind
# tense=ca ppa coarse=IV
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# tense=abs coarse=Ind
# tense=ppa coarse=IV
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# tense=pp coarse=IV
# gender=m tense=inst no=sg
# gender=m tense=inst no=sg
# case=abl gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# tense=pp no=sg
# case=loc gender=n no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# gender=f tense=inst no=sg
# tense=conj coarse=Ind
# tense=impft md no=sg case=3 coarse=FV
# tense=conj coarse=Ind
# gender=m tense=inst no=sg
# case=loc gender=f no=du coarse=Noun
# tense=conj coarse=Ind
# case=nom gender=n no=sg coarse=Noun
# tense=pfp no=sg
# tense=pp no=sg
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# case=acc gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# tense=pr md no=sg case=3 coarse=FV
# tense=conj coarse=Ind
# tense=conj coarse=Ind
# gender=f tense=inst no=sg
# tense=pp no=pl
# gender=m tense=inst no=pl
# tense=conj coarse=Ind
# case=g gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=abs coarse=Ind
# case=nom gender=f no=sg coarse=Noun
# gender=n tense=inst no=pl
# tense=conj coarse=Ind
# tense=pft no=sg case=3 coarse=FV
# tense=conj coarse=Ind
# gender=n tense=inst no=sg
# case=nom gender=m no=pl coarse=Noun
# tense=pr md no=pl case=3 coarse=FV
# case=g gender=m no=sg coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# tense=aor no=sg case=3 coarse=FV
# tense=adv coarse=adv
# case=g gender=n no=pl coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# tense=conj coarse=Ind
# case=nom gender=n no=sg coarse=Noun
# tense=fut no=sg case=3 coarse=FV
# tense=conj coarse=Ind
# tense=pp no=pl
# tense=conj coarse=Ind
# case=g gender=m no=pl coarse=Noun
# tense=conj coarse=Ind
# case=nom gender=n no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=loc gender=m no=sg coarse=Noun
# case=loc gender=n no=pl coarse=Noun
# case=loc gender=n no=pl coarse=Noun
# case=nom gender=* no=sg coarse=Noun
# tense=conj coarse=Ind
# tense=conj coarse=Ind
# case=nom gender=n no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# tense=pr no=sg case=1 coarse=FV
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# case=g gender=m no=sg coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# tense=impft md no=sg case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=g gender=n no=sg coarse=Noun
# case=acc gender=n no=pl coarse=Noun
# case=acc gender=n no=pl coarse=Noun
# case=loc gender=f no=sg coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# tense=conj coarse=Ind
# tense=ca pr no=sg case=3 coarse=FV
# tense=part coarse=Ind
# tense=pr md no=pl case=3 coarse=FV
# case=nom gender=m no=pl coarse=Noun
# case=abl gender=f no=pl coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# case=g gender=n no=pl coarse=Noun
# case=g gender=m no=sg coarse=Noun
# case=nom gender=f no=pl coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# case=g gender=m no=pl coarse=Noun
# case=dat gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# case=g gender=m no=pl coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# tense=pp no=sg
# case=loc gender=m no=pl coarse=Noun
# case=nom gender=m no=pl coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# tense=pp no=pl
# case=g gender=m no=pl coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# tense=imp no=sg case=2 coarse=FV
# case=nom gender=f no=sg coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=n no=du coarse=Noun
# case=dat gender=n no=sg coarse=Noun
# case=dat gender=n no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# case=loc gender=n no=sg coarse=Noun
# tense=ca impft no=sg case=3 coarse=FV
# case=voc gender=n no=sg coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# tense=imp no=sg case=2 coarse=FV
# tense=adv coarse=adv
# case=i gender=n no=sg coarse=Noun
# case=i gender=n no=sg coarse=Noun
# case=abl gender=n no=pl coarse=Noun
# case=nom gender=n no=pl coarse=Noun
# tense=pp coarse=IV
# tense=conj coarse=Ind
# case=nom gender=f no=sg coarse=Noun
# case=g gender=m no=pl coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=abl gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# tense=conj coarse=Ind
# tense=impft md no=sg case=3 coarse=FV
# case=nom gender=f no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=pp no=sg
# case=g gender=* no=sg coarse=Noun
# case=loc gender=n no=sg coarse=Noun
# case=loc gender=n no=sg coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# case=i gender=m no=sg coarse=Noun
# tense=adv coarse=adv
# case=nom gender=m no=du coarse=Noun
# tense=aor no=sg case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# gender=m tense=inst no=pl
# tense=conj coarse=Ind
# case=acc gender=m no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# tense=conj coarse=Ind
# case=g gender=m no=sg coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=acc gender=f no=sg coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# tense=abs coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# tense=ppa coarse=IV
# case=g gender=m no=sg coarse=Noun
# gender=f tense=inst no=sg
# case=nom gender=m no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# tense=adv coarse=adv
# tense=abs coarse=Ind
# case=g gender=m no=sg coarse=Noun
# case=g gender=m no=sg coarse=Noun
# tense=prep coarse=Ind
# case=loc gender=m no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# tense=inf coarse=IV
# case=abl gender=n no=pl coarse=Noun
# tense=pp coarse=IV
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=g gender=m no=sg coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=g gender=m no=pl coarse=Noun
# gender=m tense=inst no=pl
# tense=conj coarse=Ind
# case=nom gender=n no=pl coarse=Noun
# tense=impft no=pl case=3 coarse=FV
# case=abl gender=n no=pl coarse=Noun
# case=nom gender=m no=pl coarse=Noun
# tense=pr no=pl case=3 coarse=FV
# case=i gender=m no=pl coarse=Noun
# case=i gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# tense=adv coarse=adv
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=pl coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=loc gender=n no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=ca abs coarse=Ind
# case=loc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=ca impft no=sg case=3 coarse=FV
# case=nom gender=n no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# gender=f tense=inst no=sg
# case=abl gender=f no=sg coarse=Noun
# tense=pp no=sg
# case=nom gender=n no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# tense=conj coarse=Ind
# tense=impft md no=sg case=3 coarse=FV
# tense=adv coarse=adv
# case=loc gender=m no=sg coarse=Noun
# case=nom gender=* no=sg coarse=Noun
# tense=prep coarse=Ind
# case=g gender=m no=sg coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# tense=pr no=sg case=1 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=f no=pl coarse=Noun
# case=acc gender=f no=pl coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# gender=n tense=inst no=pl
# case=nom gender=m no=sg coarse=Noun
# case=abl gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=g gender=f no=pl coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# tense=impft no=sg case=3 coarse=FV
# case=g gender=m no=pl coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# case=g gender=m no=pl coarse=Noun
# case=g gender=f no=pl coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# tense=conj coarse=Ind
# tense=impft no=sg case=3 coarse=FV
# case=nom gender=m no=pl coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# gender=f tense=inst no=sg
# gender=f tense=inst no=sg
# gender=f tense=inst no=sg
# tense=conj coarse=Ind
# case=acc gender=m no=sg coarse=Noun
# tense=pft no=pl case=3 coarse=FV
# tense=conj coarse=Ind
# case=i gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=ca abs coarse=Ind
# case=loc gender=m no=sg coarse=Noun
# tense=ppr coarse=IV
# case=nom gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=g gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# case=g gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# tense=abs coarse=Ind
# case=nom gender=n no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# tense=pft no=sg case=3 coarse=FV
# case=nom gender=f no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# tense=inf coarse=IV
# tense=pp coarse=IV
# case=nom gender=m no=sg coarse=Noun
# case=g gender=f no=sg coarse=Noun
# case=nom gender=n no=pl coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=loc gender=n no=sg coarse=Noun
# tense=pr no=du case=3 coarse=FV
# case=g gender=n no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=pr no=du case=3 coarse=FV
# case=loc gender=n no=pl coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# tense=abs coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=inf coarse=IV
# case=loc gender=f no=sg coarse=Noun
# tense=pp coarse=IV
# case=g gender=m no=sg coarse=Noun
# case=loc gender=m no=pl coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# tense=conj coarse=Ind
# case=dat gender=f no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=n no=sg coarse=Noun
# tense=pr md no=sg case=3 coarse=FV
# gender=m tense=inst no=pl
# case=g gender=* no=sg coarse=Noun
# tense=conj coarse=Ind
# case=g gender=* no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# tense=part coarse=Ind
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=loc gender=m no=sg coarse=Noun
# case=g gender=n no=sg coarse=Noun
# case=g gender=n no=sg coarse=Noun
# case=nom gender=m no=pl coarse=Noun
# tense=conj coarse=Ind
# tense=pr no=pl case=3 coarse=FV
# case=acc gender=m no=pl coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# tense=pr no=pl case=3 coarse=FV
# tense=conj coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# case=acc gender=n no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# case=dat gender=n no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# tense=conj coarse=Ind
# tense=pr md no=sg case=1 coarse=FV
# case=acc gender=n no=sg coarse=Noun
# tense=conj coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=pr md no=sg
# case=acc gender=n no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# tense=conj coarse=Ind
# case=nom gender=f no=sg coarse=Noun
# gender=f tense=inst no=sg
# tense=conj coarse=Ind
# case=acc gender=m no=sg coarse=Noun
# gender=m tense=inst no=sg
# case=loc gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# gender=m tense=inst no=du
# gender=m tense=inst no=du
# case=abl gender=m no=sg coarse=Noun
# case=loc gender=n no=sg coarse=Noun
# tense=pft no=sg case=3 coarse=FV
# case=nom gender=n no=sg coarse=Noun
# tense=prep coarse=Ind
# case=g gender=* no=sg coarse=Noun
# case=g gender=f no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=m no=pl coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# tense=pr no=pl case=3 coarse=FV
# tense=imp no=sg case=2 coarse=FV
# case=g gender=* no=sg coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# case=nom gender=* no=sg coarse=Noun
# tense=pr no=sg case=2 coarse=FV
# tense=part coarse=Ind
# tense=pr no=pl case=3 coarse=FV
# case=nom gender=m no=pl coarse=Noun
# case=loc gender=n no=sg coarse=Noun
# case=g gender=m no=sg coarse=Noun
# case=abl gender=n no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=m no=pl coarse=Noun
# case=nom gender=m no=pl coarse=Noun
# case=g gender=n no=sg coarse=Noun
# case=loc gender=n no=sg coarse=Noun
# case=nom gender=m no=pl coarse=Noun
# tense=part coarse=Ind
# tense=pr no=pl case=3 coarse=FV
# tense=part coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=pl coarse=Noun
# tense=inf coarse=IV
# tense=part coarse=Ind
# tense=pp coarse=IV
# case=dat gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=g gender=n no=du coarse=Noun
# case=g gender=n no=du coarse=Noun
# case=g gender=n no=du coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# tense=prep coarse=Ind
# case=loc gender=n no=sg coarse=Noun
# case=loc gender=f no=sg coarse=Noun
# tense=abs coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=pp coarse=IV
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=aor no=sg case=3 coarse=FV
# case=i gender=f no=sg coarse=Noun
# case=i gender=f no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=abl gender=n no=sg coarse=Noun
# case=g gender=n no=du coarse=Noun
# case=g gender=f no=du coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# tense=pp coarse=IV
# case=dat gender=f no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# gender=f tense=inst no=sg
# gender=f tense=inst no=sg
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=abl gender=n no=pl coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=impft no=sg case=2 coarse=FV
# tense=adv coarse=adv
# tense=conj coarse=Ind
# case=acc gender=n no=sg coarse=Noun
# tense=part coarse=Ind
# tense=prep coarse=Ind
# tense=ca fut no=sg case=1 coarse=FV
# case=nom gender=n no=sg coarse=Noun
# case=nom gender=m no=pl coarse=Noun
# tense=conj coarse=Ind
# case=nom gender=m no=pl coarse=Noun
# tense=conj coarse=Ind
# case=nom gender=* no=sg coarse=Noun
# tense=pr no=sg case=1 coarse=FV
# tense=adv coarse=adv
# tense=part coarse=Ind
# tense=fut no=pl case=3 coarse=FV
# tense=conj coarse=Ind
# case=g gender=* no=sg coarse=Noun
# tense=prep coarse=Ind
# case=g gender=m no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# case=nom gender=m no=pl coarse=Noun
# tense=pr no=pl case=3 coarse=FV
# case=nom gender=f no=sg coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# gender=m tense=inst no=pl
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=g gender=f no=pl coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# tense=conj coarse=Ind
# case=nom gender=f no=pl coarse=Noun
# case=nom gender=f no=pl coarse=Noun
# tense=conj coarse=Ind
# tense=pft md no=pl case=3 coarse=FV
# case=g gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=ind coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# case=g gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=pp coarse=IV
# gender=f tense=inst no=pl
# case=g gender=m no=pl coarse=Noun
# case=g gender=m no=pl coarse=Noun
# case=abl gender=n no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# case=g gender=n no=pl coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=pft md no=sg case=3 coarse=FV
# case=acc gender=m no=sg coarse=Noun
# tense=prep coarse=Ind
# case=nom gender=n no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=part coarse=Ind
# tense=prep coarse=Ind
# tense=pr no=sg case=3 coarse=FV
# tense=adv coarse=adv
# case=i gender=n no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# tense=conj coarse=Ind
# case=nom gender=n no=sg coarse=Noun
# tense=impft md no=sg case=3 coarse=FV
# case=loc gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=m no=pl coarse=Noun
# case=acc gender=m no=pl coarse=Noun
# tense=impft no=sg case=3 coarse=FV
# case=nom gender=m no=pl coarse=Noun
# case=dat gender=m no=pl coarse=Noun
# tense=pr md no=pl case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=dat gender=m no=du coarse=Noun
# case=dat gender=m no=du coarse=Noun
# tense=abs coarse=Ind
# case=acc gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# case=dat gender=n no=sg coarse=Noun
# tense=ca abs coarse=Ind
# case=acc gender=n no=sg coarse=Noun
# tense=inf coarse=IV
# case=acc gender=n no=sg coarse=Noun
# tense=pp coarse=IV
# tense=part coarse=Ind
# case=loc gender=m no=sg coarse=Noun
# case=nom gender=m no=pl coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# tense=aor no=sg case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# case=abl gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=abs coarse=Ind
# case=acc gender=f no=sg coarse=Noun
# tense=conj coarse=Ind
# tense=fut no=sg case=3 coarse=FV
# tense=pr no=sg case=3 coarse=FV
# case=acc gender=n no=sg coarse=Noun
# tense=conj coarse=Ind
# tense=conj coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# tense=pr no=sg case=3 coarse=FV
# tense=part coarse=Ind
# case=nom gender=n no=sg coarse=Noun
# tense=prep coarse=Ind
# tense=pr no=sg case=3 coarse=FV
# tense=conj coarse=Ind
# case=loc gender=m no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# tense=pr no=sg case=3 coarse=FV
# tense=conj coarse=Ind
# gender=m tense=inst no=pl
# tense=conj coarse=Ind
# case=loc gender=n no=sg coarse=Noun
# tense=pp no=sg
# gender=m tense=inst no=pl
# tense=pft md no=sg case=3 coarse=FV
# tense=conj coarse=Ind
# tense=conj coarse=Ind
# case=abl gender=n no=sg coarse=Noun
# case=acc gender=n no=pl coarse=Noun
# tense=des pr md no=sg case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# gender=m tense=inst no=sg
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# tense=pr md no=sg case=3 coarse=FV
# case=nom gender=* no=sg coarse=Noun
# case=g gender=* no=sg coarse=Noun
# case=g gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=pr no=sg case=1 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=n no=pl coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# tense=part coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# gender=f tense=inst no=sg
# case=acc gender=m no=sg coarse=Noun
# case=g gender=m no=pl coarse=Noun
# case=g gender=n no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# tense=conj coarse=Ind
# case=loc gender=n no=pl coarse=Noun
# tense=pft no=sg case=2 coarse=FV
# case=acc gender=f no=sg coarse=Noun
# tense=abs coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# tense=abs coarse=Ind
# case=acc gender=n no=sg coarse=Noun
# tense=pp coarse=IV
# case=nom gender=f no=sg coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# case=nom gender=f no=pl coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# tense=abs coarse=Ind
# case=acc gender=n no=sg coarse=Noun
# tense=impft no=sg case=3 coarse=FV
# case=acc gender=m no=sg coarse=Noun
# case=g gender=* no=sg coarse=Noun
# case=g gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# case=acc gender=m no=sg coarse=Noun
# tense=ca abs coarse=Ind
# case=acc gender=n no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=ca pp coarse=IV
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# case=acc gender=n no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# case=nom gender=f no=pl coarse=Noun
# case=nom gender=f no=pl coarse=Noun
# case=loc gender=f no=pl coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# tense=impft no=pl case=3 coarse=FV
# case=acc gender=m no=du coarse=Noun
# tense=impft no=sg case=3 coarse=FV
# case=i gender=m no=pl coarse=Noun
# gender=m tense=inst no=sg
# case=nom gender=n no=sg coarse=Noun
# tense=opt no=sg case=3 coarse=FV
# tense=conj coarse=Ind
# tense=pp coarse=IV
# tense=conj coarse=Ind
# case=acc gender=* no=sg coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# tense=imp no=sg case=2 coarse=FV
# case=abl gender=n no=sg coarse=Noun
# tense=prep coarse=Ind
# case=abl gender=n no=sg coarse=Noun
# case=g gender=* no=sg coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# case=dat gender=m no=sg coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# tense=part coarse=Ind
# case=acc gender=f no=sg coarse=Noun
# case=nom gender=m no=pl coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# tense=part coarse=Ind
# case=acc gender=f no=sg coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# tense=part coarse=Ind
# tense=opt no=sg case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=loc gender=n no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=g gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# tense=adv coarse=adv
# case=nom gender=* no=sg coarse=Noun
# tense=part coarse=Ind
# tense=opt no=sg case=1 coarse=FV
# tense=adv coarse=adv
# case=acc gender=n no=sg coarse=Noun
# case=acc gender=* no=sg coarse=Noun
# case=loc gender=n no=sg coarse=Noun
# tense=part coarse=Ind
# tense=ca imp no=sg case=2 coarse=FV
# case=acc gender=n no=sg coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# tense=conj coarse=Ind
# case=acc gender=m no=sg coarse=Noun
# tense=prep coarse=Ind
# tense=pr no=sg case=3 coarse=FV
# tense=conj coarse=Ind
# case=g gender=* no=sg coarse=Noun
# tense=adv coarse=adv
# tense=fut no=sg case=3 coarse=FV
# tense=adv coarse=adv
# case=nom gender=* no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# tense=fut no=sg case=1 coarse=FV
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# case=nom gender=f no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=* no=sg coarse=Noun
# case=g gender=* no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=loc gender=n no=sg coarse=Noun
# case=loc gender=n no=sg coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=pr no=sg case=1 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# case=acc gender=n no=pl coarse=Noun
# case=acc gender=n no=pl coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=impft md no=sg case=3 coarse=FV
# tense=adv coarse=adv
# case=g gender=* no=sg coarse=Noun
# case=i gender=m no=sg coarse=Noun
# tense=prep coarse=Ind
# case=g gender=m no=sg coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# tense=ppr coarse=IV
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=* no=sg coarse=Noun
# tense=pp coarse=IV
# gender=m tense=inst no=sg
# tense=conj coarse=Ind
# case=nom gender=n no=sg coarse=Noun
# case=g gender=f no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=g gender=m no=sg coarse=Noun
# case=loc gender=f no=sg coarse=Noun
# tense=conj coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=pft md no=sg case=3 coarse=FV
# case=acc gender=f no=sg coarse=Noun
# tense=adv coarse=adv
# tense=inf coarse=IV
# case=nom gender=f no=pl coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=ppa coarse=IV
# gender=m tense=inst no=pl
# tense=conj coarse=Ind
# tense=pp no=sg
# tense=conj coarse=Ind
# case=acc gender=f no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# case=g gender=n no=pl coarse=Noun
# tense=conj coarse=Ind
# tense=pr no=sg case=2 coarse=FV
# case=loc gender=n no=sg coarse=Noun
# case=g gender=n no=sg coarse=Noun
# tense=prep coarse=Ind
# case=nom gender=m no=pl coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=m no=pl coarse=Noun
# tense=conj coarse=Ind
# case=loc gender=m no=sg coarse=Noun
# tense=pr no=pl case=3 coarse=FV
# case=i gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# case=acc gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# case=nom gender=n no=sg coarse=Noun
# tense=impft no=sg case=3 coarse=FV
# case=loc gender=n no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=pp coarse=IV
# case=voc gender=m no=sg coarse=Noun
# case=nom gender=m no=pl coarse=Noun
# tense=conj coarse=Ind
# case=nom gender=m no=pl coarse=Noun
# tense=pr no=pl case=3 coarse=FV
# case=g gender=n no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# tense=adv coarse=adv
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=prep coarse=Ind
# tense=aor no=sg case=3 coarse=FV
# tense=adv coarse=adv
# case=g gender=* no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=dat gender=m no=sg coarse=Noun
# tense=pp coarse=IV
# case=g gender=n no=sg coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# tense=ppr coarse=IV
# case=acc gender=f no=pl coarse=Noun
# tense=conj coarse=Ind
# case=acc gender=f no=pl coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=g gender=m no=pl coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=g gender=f no=pl coarse=Noun
# case=g gender=f no=pl coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# tense=impft md no=sg case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=g gender=f no=sg coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# case=loc gender=n no=sg coarse=Noun
# tense=ca ppa coarse=IV
# case=loc gender=m no=pl coarse=Noun
# case=nom gender=n no=pl coarse=Noun
# tense=pr md no=pl case=3 coarse=FV
# case=nom gender=m no=pl coarse=Noun
# case=acc gender=m no=pl coarse=Noun
# tense=inf coarse=IV
# tense=part coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=n no=sg coarse=Noun
# case=g gender=f no=pl coarse=Noun
# case=g gender=f no=pl coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# case=nom gender=m no=pl coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=impft md no=pl case=3 coarse=FV
# case=nom gender=f no=sg coarse=Noun
# tense=pft no=sg case=3 coarse=FV
# gender=m tense=inst no=sg
# tense=conj coarse=Ind
# case=loc gender=m no=sg coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# tense=impft md no=sg case=3 coarse=FV
# tense=conj coarse=Ind
# tense=ind coarse=Ind
# tense=adv coarse=adv
# case=g gender=m no=sg coarse=Noun
# case=nom gender=m no=pl coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# case=g gender=* no=sg coarse=Noun
# case=nom gender=f no=pl coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=f no=sg coarse=Noun
# tense=prep coarse=Ind
# case=g gender=n no=sg coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# tense=conj coarse=Ind
# case=nom gender=m no=pl coarse=Noun
# tense=aor no=sg case=3 coarse=FV
# case=abl gender=n no=pl coarse=Noun
# case=dat gender=m no=sg coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# tense=abs coarse=Ind
# case=nom gender=f no=pl coarse=Noun
# case=nom gender=f no=pl coarse=Noun
# case=nom gender=m no=pl coarse=Noun
# tense=conj coarse=Ind
# tense=inf coarse=IV
# tense=pp coarse=IV
# case=nom gender=f no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# case=g gender=f no=sg coarse=Noun
# case=abl gender=n no=sg coarse=Noun
# case=acc gender=m no=pl coarse=Noun
# tense=conj coarse=Ind
# tense=conj coarse=Ind
# tense=pr no=sg case=3 coarse=FV
# tense=conj coarse=Ind
# case=acc gender=f no=sg coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# tense=pp coarse=IV
# case=g gender=n no=du coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# case=acc gender=f no=sg coarse=Noun
# tense=impft no=sg case=3 coarse=FV
# case=nom gender=f no=sg coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# tense=conj coarse=Ind
# tense=conj coarse=Ind
# case=nom gender=f no=sg coarse=Noun
# tense=conj coarse=Ind
# tense=conj coarse=Ind
# case=g gender=m no=sg coarse=Noun
# case=nom gender=f no=pl coarse=Noun
# case=nom gender=f no=pl coarse=Noun
# gender=n tense=inst no=pl
# case=acc gender=m no=pl coarse=Noun
# tense=conj coarse=Ind
# case=acc gender=m no=pl coarse=Noun
# case=acc gender=m no=pl coarse=Noun
# case=acc gender=m no=pl coarse=Noun
# tense=conj coarse=Ind
# tense=pr no=pl case=3 coarse=FV
# gender=m tense=inst no=sg
# gender=m tense=inst no=sg
# case=acc gender=n no=sg coarse=Noun
# tense=inf coarse=IV
# case=nom gender=m no=sg coarse=Noun
# case=g gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# case=g gender=n no=sg coarse=Noun
# case=abl gender=m no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# gender=n tense=inst no=sg
# tense=pft no=sg case=3 coarse=FV
# case=loc gender=n no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=abl gender=n no=sg coarse=Noun
# case=nom gender=f no=pl coarse=Noun
# case=loc gender=f no=sg coarse=Noun
# tense=part coarse=Ind
# case=acc gender=m no=du coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# tense=part coarse=Ind
# tense=conj coarse=Ind
# case=acc gender=n no=du coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# tense=prep coarse=Ind
# tense=adv coarse=adv
# case=nom gender=m no=sg coarse=Noun
# case=loc gender=n no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# case=nom gender=m no=pl coarse=Noun
# tense=adv coarse=adv
# case=acc gender=n no=sg coarse=Noun
# tense=part coarse=Ind
# tense=ppr coarse=IV
# tense=part coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# case=g gender=m no=pl coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# tense=pp no=sg
# case=nom gender=m no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=loc gender=n no=sg coarse=Noun
# tense=prep coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=* no=sg coarse=Noun
# case=loc gender=n no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=impft md no=sg case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=m no=pl coarse=Noun
# tense=impft no=sg case=3 coarse=FV
# tense=part coarse=Ind
# tense=conj coarse=Ind
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=f no=du coarse=Noun
# case=acc gender=f no=du coarse=Noun
# tense=prep coarse=Ind
# tense=pp coarse=IV
# case=loc gender=m no=sg coarse=Noun
# case=acc gender=n no=pl coarse=Noun
# tense=imp no=sg case=3 coarse=FV
# case=acc gender=n no=pl coarse=Noun
# tense=imp no=sg case=3 coarse=FV
# tense=conj coarse=Ind
# case=loc gender=m no=sg coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# tense=impft no=sg case=3 coarse=FV
# case=i gender=m no=sg coarse=Noun
# case=voc gender=f no=pl coarse=Noun
# tense=pr no=pl case=3 coarse=FV
# case=nom gender=m no=pl coarse=Noun
# tense=conj coarse=Ind
# case=g gender=m no=sg coarse=Noun
# case=nom gender=n no=pl coarse=Noun
# case=nom gender=m no=pl coarse=Noun
# case=g gender=n no=sg coarse=Noun
# case=nom gender=m no=pl coarse=Noun
# tense=conj coarse=Ind
# case=nom gender=m no=pl coarse=Noun
# case=nom gender=m no=pl coarse=Noun
# gender=n tense=inst no=sg
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=per fut no=pl case=3 coarse=FV
# tense=conj coarse=Ind
# case=nom gender=m no=pl coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# tense=per fut no=pl case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=pp coarse=IV
# tense=part coarse=Ind
# tense=conj coarse=Ind
# case=abl gender=n no=sg coarse=Noun
# case=dat gender=m no=sg coarse=Noun
# tense=ca pr no=sg case=3 coarse=FV
# case=nom gender=m no=pl coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# tense=conj coarse=Ind
# case=acc gender=f no=sg coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# tense=conj coarse=Ind
# tense=pr no=sg case=3 coarse=FV
# case=abl gender=n no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=des pr md no=du case=1 coarse=FV
# case=nom gender=* no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# case=dat gender=f no=sg coarse=Noun
# tense=fut no=sg case=1 coarse=FV
# case=voc gender=m no=sg coarse=Noun
# case=g gender=n no=pl coarse=Noun
# tense=prep coarse=Ind
# case=abl gender=n no=sg coarse=Noun
# case=nom gender=n no=du coarse=Noun
# tense=pr no=pl case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# case=g gender=n no=pl coarse=Noun
# gender=m tense=inst no=sg
# case=abl gender=n no=sg coarse=Noun
# tense=abs coarse=Ind
# case=acc gender=f no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# tense=conj coarse=Ind
# case=loc gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# tense=conj coarse=Ind
# case=acc gender=f no=pl coarse=Noun
# case=acc gender=f no=pl coarse=Noun
# case=g gender=m no=sg coarse=Noun
# case=acc gender=f no=pl coarse=Noun
# tense=conj coarse=Ind
# case=acc gender=f no=pl coarse=Noun
# tense=pft no=sg case=3 coarse=FV
# case=acc gender=n no=du coarse=Noun
# tense=conj coarse=Ind
# tense=adv coarse=adv
# tense=pr no=sg case=3 coarse=FV
# case=loc gender=n no=sg coarse=Noun
# tense=conj coarse=Ind
# case=acc gender=m no=sg coarse=Noun
# case=nom gender=f no=pl coarse=Noun
# tense=conj coarse=Ind
# tense=inf coarse=IV
# tense=pp coarse=IV
# case=nom gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# case=acc gender=m no=sg coarse=Noun
# tense=adv coarse=adv
# tense=ppr coarse=IV
# tense=abs coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# tense=pp coarse=IV
# gender=m tense=inst no=pl
# gender=m tense=inst no=pl
# gender=m tense=inst no=pl
# tense=conj coarse=Ind
# case=acc gender=m no=sg coarse=Noun
# case=abl gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=pft no=sg case=3 coarse=FV
# case=acc gender=* no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=ca abs coarse=Ind
# case=loc gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# case=g gender=* no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=abs coarse=Ind
# case=g gender=* no=sg coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# tense=imp no=sg case=3 coarse=FV
# case=voc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=imp no=sg case=2 coarse=FV
# case=acc gender=m no=sg coarse=Noun
# tense=pr no=pl case=3 coarse=FV
# case=nom gender=m no=pl coarse=Noun
# tense=conj coarse=Ind
# tense=conj coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# gender=m tense=inst no=pl
# tense=pp no=sg
# tense=part coarse=Ind
# case=i gender=m no=sg coarse=Noun
# case=i gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=abl gender=n no=sg coarse=Noun
# tense=pr no=sg case=2 coarse=FV
# case=nom gender=* no=sg coarse=Noun
# case=nom gender=* no=sg coarse=Noun
# tense=imp no=sg case=2 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# tense=part coarse=Ind
# case=loc gender=m no=pl coarse=Noun
# case=g gender=* no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=imp no=sg case=2 coarse=FV
# tense=conj coarse=Ind
# tense=conj coarse=Ind
# case=loc gender=n no=sg coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# tense=pft no=sg case=1 coarse=FV
# case=g gender=m no=sg coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# tense=opt no=sg case=3 coarse=FV
# tense=conj coarse=Ind
# tense=imp no=sg case=2 coarse=FV
# tense=conj coarse=Ind
# case=nom gender=f no=sg coarse=Noun
# tense=conj coarse=Ind
# tense=opt no=sg case=3 coarse=FV
# case=acc gender=n no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# tense=opt no=sg case=3 coarse=FV
# tense=conj coarse=Ind
# case=nom gender=n no=sg coarse=Noun
# tense=opt no=sg case=3 coarse=FV
# case=nom gender=n no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# tense=opt no=sg case=3 coarse=FV
# tense=conj coarse=Ind
# case=nom gender=n no=sg coarse=Noun
# tense=conj coarse=Ind
# tense=opt no=sg case=3 coarse=FV
# case=g gender=m no=sg coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# tense=conj coarse=Ind
# tense=adv coarse=adv
# case=nom gender=m no=pl coarse=Noun
# case=loc gender=n no=sg coarse=Noun
# tense=ca pp coarse=IV
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=adv coarse=adv
# case=nom gender=m no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# tense=part coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# tense=impft no=sg case=3 coarse=FV
# tense=conj coarse=Ind
# case=loc gender=n no=sg coarse=Noun
# case=g gender=f no=pl coarse=Noun
# case=abl gender=n no=pl coarse=Noun
# tense=abs coarse=Ind
# case=g gender=n no=du coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=part coarse=Ind
# tense=aor no=sg case=3 coarse=FV
# tense=adv coarse=adv
# tense=part coarse=Ind
# case=acc gender=m no=pl coarse=Noun
# case=acc gender=m no=pl coarse=Noun
# case=acc gender=m no=pl coarse=Noun
# case=dat gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=ca pr no=pl case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# tense=imp no=sg case=2 coarse=FV
# case=nom gender=* no=sg coarse=Noun
# case=voc gender=m no=sg coarse=Noun
# tense=adv coarse=adv
# tense=conj coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# tense=adv coarse=adv
# case=g gender=* no=sg coarse=Noun
# case=loc gender=f no=sg coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# case=dat gender=n no=sg coarse=Noun
# tense=part coarse=Ind
# tense=pp coarse=IV
# case=voc gender=m no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# tense=conj coarse=Ind
# case=loc gender=n no=sg coarse=Noun
# case=nom gender=* no=sg coarse=Noun
# case=loc gender=n no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=prep coarse=Ind
# tense=impft no=sg case=1 coarse=FV
# tense=part coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=n no=pl coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# tense=impft no=sg case=3 coarse=FV
# tense=impft no=sg case=3 coarse=FV
# tense=conj coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# case=acc gender=m no=pl coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=n no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# tense=pp no=sg
# tense=conj coarse=Ind
# tense=pr no=sg case=3 coarse=FV
# tense=conj coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# case=acc gender=m no=pl coarse=Noun
# case=acc gender=m no=pl coarse=Noun
# tense=imp no=sg case=3 coarse=FV
# tense=conj coarse=Ind
# case=dat gender=m no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# tense=adv coarse=adv
# case=nom gender=m no=sg coarse=Noun
# tense=impft no=sg case=3 coarse=FV
# case=nom gender=* no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# case=acc gender=m no=sg coarse=Noun
# tense=opt no=sg case=2 coarse=FV
# case=g gender=m no=sg coarse=Noun
# case=i gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=ppa coarse=IV
# case=acc gender=n no=sg coarse=Noun
# tense=abs coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=pp coarse=IV
# case=loc gender=m no=sg coarse=Noun
# case=g gender=m no=sg coarse=Noun
# case=acc gender=n no=du coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# case=loc gender=f no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=ca pfp coarse=IV
# case=loc gender=m no=sg coarse=Noun
# tense=prep coarse=Ind
# case=acc gender=m no=sg coarse=Noun
# case=g gender=* no=sg coarse=Noun
# case=g gender=m no=sg coarse=Noun
# case=g gender=m no=sg coarse=Noun
# case=g gender=f no=sg coarse=Noun
# case=i gender=m no=sg coarse=Noun
# case=nom gender=m no=pl coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=g gender=* no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=ca pfp coarse=IV
# tense=conj coarse=Ind
# case=loc gender=m no=sg coarse=Noun
# case=loc gender=f no=pl coarse=Noun
# case=loc gender=f no=pl coarse=Noun
# case=loc gender=f no=pl coarse=Noun
# case=nom gender=f no=pl coarse=Noun
# case=nom gender=f no=pl coarse=Noun
# case=nom gender=f no=pl coarse=Noun
# ...
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=pfp coarse=IV
# tense=conj coarse=Ind
# case=nom gender=f no=sg coarse=Noun
# tense=per fut md no=sg case=3 coarse=FV
# tense=part coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# case=loc gender=f no=sg coarse=Noun
# case=loc gender=f no=sg coarse=Noun
# case=loc gender=n no=sg coarse=Noun
# tense=ca inf coarse=IV
# tense=pr no=sg case=3 coarse=FV
# tense=part coarse=Ind
# tense=part coarse=Ind
# tense=pfp coarse=IV
# case=acc gender=m no=sg coarse=Noun
# tense=adv coarse=adv
# tense=inf coarse=IV
# case=i gender=m no=sg coarse=Noun
# tense=prep coarse=Ind
# tense=conj coarse=Ind
# case=nom gender=f no=sg coarse=Noun
# tense=conj coarse=Ind
# case=nom gender=f no=sg coarse=Noun
# case=loc gender=m no=pl coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=* no=sg coarse=Noun
# tense=conj coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# tense=inf coarse=IV
# tense=pr no=sg case=1 coarse=FV
# tense=impft no=sg case=1 coarse=FV
# tense=conj coarse=Ind
# tense=pr no=sg case=1 coarse=FV
# case=acc gender=m no=sg coarse=Noun
# tense=ind coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=i gender=m no=sg coarse=Noun
# case=i gender=n no=sg coarse=Noun
# tense=ppr coarse=IV
# case=acc gender=m no=sg coarse=Noun
# tense=impft no=sg case=3 coarse=FV
# case=loc gender=f no=sg coarse=Noun
# case=g gender=n no=pl coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=impft md no=pl case=1 coarse=FV
# case=g gender=n no=pl coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# case=nom gender=m no=pl coarse=Noun
# tense=pr no=pl case=3 coarse=FV
# case=nom gender=f no=sg coarse=Noun
# case=abl gender=n no=sg coarse=Noun
# case=acc gender=m no=du coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# case=g gender=n no=sg coarse=Noun
# case=g gender=m no=sg coarse=Noun
# case=nom gender=f no=pl coarse=Noun
# case=abl gender=n no=sg coarse=Noun
# tense=conj coarse=Ind
# case=acc gender=f no=sg coarse=Noun
# tense=impft no=pl case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=g gender=m no=pl coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# tense=impft no=sg case=3 coarse=FV
# case=g gender=f no=sg coarse=Noun
# case=acc gender=n no=pl coarse=Noun
# case=nom gender=n no=pl coarse=Noun
# tense=part coarse=Ind
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=m no=pl coarse=Noun
# case=nom gender=m no=pl coarse=Noun
# tense=pr no=pl case=3 coarse=FV
# case=g gender=* no=sg coarse=Noun
# case=g gender=m no=pl coarse=Noun
# case=loc gender=n no=pl coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=g gender=m no=sg coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=abl gender=n no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=impft no=sg case=3 coarse=FV
# tense=part coarse=Ind
# case=i gender=m no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# case=g gender=f no=pl coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# case=g gender=m no=sg coarse=Noun
# case=g gender=m no=sg coarse=Noun
# case=i gender=n no=sg coarse=Noun
# tense=part coarse=Ind
# case=loc gender=m no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=g gender=m no=pl coarse=Noun
# case=g gender=m no=pl coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=dat gender=n no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=* no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=pr no=sg case=1 coarse=FV
# case=i gender=m no=sg coarse=Noun
# gender=f tense=inst no=pl
# tense=pp no=sg
# case=nom gender=f no=sg coarse=Noun
# tense=impft md no=sg case=3 coarse=FV
# case=loc gender=m no=pl coarse=Noun
# case=loc gender=m no=pl coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=impft no=sg case=3 coarse=FV
# gender=f tense=inst no=sg
# gender=m tense=inst no=sg
# tense=conj coarse=Ind
# case=voc gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# tense=impft no=sg case=3 coarse=FV
# case=acc gender=f no=sg coarse=Noun
# case=nom gender=m no=pl coarse=Noun
# tense=imp no=pl case=3 coarse=FV
# case=nom gender=f no=du coarse=Noun
# case=acc gender=n no=pl coarse=Noun
# tense=imp no=du case=2 coarse=FV
# case=g gender=m no=pl coarse=Noun
# case=nom gender=m no=pl coarse=Noun
# tense=imp no=pl case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# tense=imp no=sg case=3 coarse=FV
# case=nom gender=m no=pl coarse=Noun
# case=acc gender=m no=pl coarse=Noun
# tense=imp md no=pl case=2 coarse=FV
# case=nom gender=m no=pl coarse=Noun
# case=g gender=m no=sg coarse=Noun
# gender=f tense=inst no=sg
# tense=imp md no=pl case=3 coarse=FV
# case=g gender=m no=pl coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=imp md no=sg case=3 coarse=FV
# case=loc gender=n no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=impft no=sg case=3 coarse=FV
# case=acc gender=n no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# tense=conj coarse=Ind
# tense=impft no=sg case=3 coarse=FV
# tense=pp no=sg
# case=nom gender=m no=sg coarse=Noun
# case=dat gender=f no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=g gender=m no=sg coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=i gender=m no=sg coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=abl gender=m no=sg coarse=Noun
# case=nom gender=n no=pl coarse=Noun
# tense=impft no=pl case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=loc gender=m no=pl coarse=Noun
# gender=m tense=inst no=sg
# tense=pr no=sg case=3 coarse=FV
# case=abl gender=n no=pl coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# tense=pr md no=pl case=3 coarse=FV
# case=dat gender=m no=sg coarse=Noun
# tense=imp no=sg case=2 coarse=FV
# tense=conj coarse=Ind
# case=acc gender=n no=pl coarse=Noun
# case=acc gender=f no=sg coarse=Noun
# case=g gender=m no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=abl gender=f no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=pr no=pl case=3 coarse=FV
# case=nom gender=m no=pl coarse=Noun
# case=acc gender=m no=pl coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# tense=impft no=pl case=3 coarse=FV
# gender=m tense=inst no=pl
# case=nom gender=m no=pl coarse=Noun
# tense=pr md no=pl case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=m no=pl coarse=Noun
# tense=impft no=sg case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=acc gender=m no=du coarse=Noun
# case=i gender=m no=pl coarse=Noun
# tense=ca pr no=du case=3 coarse=FV
# case=g gender=n no=sg coarse=Noun
# gender=m tense=inst no=pl
# tense=pr no=pl case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=* no=pl coarse=Noun
# tense=pr no=pl case=3 coarse=FV
# case=acc gender=m no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=pr md no=du case=3 coarse=FV
# case=voc gender=m no=du coarse=Noun
# case=nom gender=m no=pl coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=pr md no=pl case=3 coarse=FV
# case=g gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=part coarse=Ind
# tense=pr md no=pl case=3 coarse=FV
# case=nom gender=m no=pl coarse=Noun
# case=dat gender=m no=sg coarse=Noun
# tense=pr md no=pl case=3 coarse=FV
# case=nom gender=m no=pl coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=dat gender=m no=sg coarse=Noun
# tense=pr md no=sg case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=pr md no=sg case=3 coarse=FV
# case=acc gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=pr md no=sg case=3 coarse=FV
# case=nom gender=m no=pl coarse=Noun
# case=acc gender=n no=pl coarse=Noun
# tense=pr no=pl case=3 coarse=FV
# case=nom gender=n no=pl coarse=Noun
# tense=pr no=pl case=3 coarse=FV
# tense=conj coarse=Ind
# gender=n tense=inst no=sg
# case=nom gender=m no=pl coarse=Noun
# tense=impft md no=pl case=3 coarse=FV
# case=abl gender=m no=sg coarse=Noun
# case=g gender=f no=sg coarse=Noun
# case=nom gender=n no=pl coarse=Noun
# tense=impft md no=pl case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# gender=f tense=inst no=sg
# tense=conj coarse=Ind
# case=g gender=f no=sg coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# tense=impft md no=sg case=3 coarse=FV
# case=nom gender=m no=pl coarse=Noun
# case=acc gender=m no=pl coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=impft no=pl case=3 coarse=FV
# case=loc gender=m no=sg coarse=Noun
# case=nom gender=f no=pl coarse=Noun
# tense=impft no=pl case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=impft no=sg case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=impft no=sg case=3 coarse=FV
# tense=conj coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# case=acc gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# tense=conj coarse=Ind
# tense=impft no=sg case=3 coarse=FV
# gender=m tense=inst no=sg
# case=nom gender=m no=sg coarse=Noun
# tense=impft md no=sg case=3 coarse=FV
# case=acc gender=n no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=impft no=pl case=1 coarse=FV
# case=g gender=m no=sg coarse=Noun
# case=abl gender=n no=sg coarse=Noun
# case=nom gender=m no=du coarse=Noun
# tense=impft no=du case=3 coarse=FV
# case=dat gender=m no=pl coarse=Noun
# case=acc gender=m no=pl coarse=Noun
# tense=impft no=sg case=1 coarse=FV
# case=g gender=n no=sg coarse=Noun
# case=i gender=m no=sg coarse=Noun
# case=g gender=f no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=impft no=sg case=3 coarse=FV
# case=loc gender=f no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=g gender=f no=pl coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=i gender=m no=pl coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=voc gender=f no=sg coarse=Noun
# tense=pr no=sg case=1 coarse=FV
# case=g gender=f no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=abl gender=n no=sg coarse=Noun
# tense=prep coarse=Ind
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=aor no=sg case=3 coarse=FV
# case=g gender=f no=sg coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=g gender=m no=pl coarse=Noun
# case=loc gender=f no=sg coarse=Noun
# tense=conj coarse=Ind
# tense=conj coarse=Ind
# case=nom gender=n no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=g gender=f no=pl coarse=Noun
# gender=n tense=inst no=sg
# case=loc gender=m no=pl coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# tense=pr md no=sg case=3 coarse=FV
# case=g gender=m no=pl coarse=Noun
# case=i gender=f no=pl coarse=Noun
# tense=pr md no=sg case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=dat gender=f no=pl coarse=Noun
# tense=pp no=sg
# tense=pr no=pl case=3 coarse=FV
# case=nom gender=m no=pl coarse=Noun
# case=abl gender=f no=du coarse=Noun
# tense=pr md no=sg case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=g gender=m no=sg coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# case=nom gender=f no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=f no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=f no=pl coarse=Noun
# case=g gender=m no=sg coarse=Noun
# case=nom gender=n no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=loc gender=n no=sg coarse=Noun
# case=g gender=m no=sg coarse=Noun
# case=loc gender=n no=sg coarse=Noun
# tense=pr md no=du case=3 coarse=FV
# case=nom gender=m no=pl coarse=Noun
# case=acc gender=f no=pl coarse=Noun
# tense=pr no=pl case=3 coarse=FV
# case=acc gender=f no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=g gender=n no=sg coarse=Noun
# case=nom gender=f no=pl coarse=Noun
# tense=pr no=pl case=3 coarse=FV
# tense=pp coarse=IV
# case=nom gender=n no=du coarse=Noun
# case=nom gender=n no=du coarse=Noun
# tense=ind coarse=Ind
# case=loc gender=m no=sg coarse=Noun
# tense=pr no=pl case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=g gender=m no=sg coarse=Noun
# gender=f tense=inst no=sg
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=m no=pl coarse=Noun
# case=acc gender=m no=pl coarse=Noun
# tense=pr no=pl case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=m no=du coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=m no=pl coarse=Noun
# case=acc gender=m no=pl coarse=Noun
# tense=pr no=pl case=3 coarse=FV
# case=acc gender=m no=pl coarse=Noun
# tense=pr no=pl case=3 coarse=FV
# case=nom gender=m no=pl coarse=Noun
# case=acc gender=n no=pl coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=n no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=n no=sg coarse=Noun
# case=acc gender=m no=pl coarse=Noun
# tense=ca ppr coarse=IV
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=acc gender=m no=sg coarse=Noun
# tense=part coarse=Ind
# tense=pr no=sg case=1 coarse=FV
# case=acc gender=m no=pl coarse=Noun
# tense=part coarse=Ind
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=g gender=m no=pl coarse=Noun
# case=loc gender=m no=pl coarse=Noun
# case=nom gender=m no=pl coarse=Noun
# tense=pr no=pl case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=dat gender=m no=pl coarse=Noun
# case=acc gender=m no=pl coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=dat gender=m no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=m no=pl coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# tense=pr no=pl case=3 coarse=FV
# case=abl gender=n no=pl coarse=Noun
# tense=pr no=pl case=3 coarse=FV
# case=nom gender=m no=pl coarse=Noun
# case=g gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=abl gender=m no=sg coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=loc gender=m no=sg coarse=Noun
# tense=pfp no=pl
# case=nom gender=m no=pl coarse=Noun
# tense=pr no=pl case=3 coarse=FV
# case=abl gender=m no=pl coarse=Noun
# case=nom gender=n no=pl coarse=Noun
# tense=pr no=pl case=3 coarse=FV
# case=abl gender=m no=pl coarse=Noun
# tense=pr no=pl case=3 coarse=FV
# case=nom gender=m no=pl coarse=Noun
# case=acc gender=m no=sg coarse=Noun
# case=abl gender=m no=sg coarse=Noun
# case=nom gender=m no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=nom gender=m no=sg coarse=Noun
# case=dat gender=m no=sg coarse=Noun
# tense=pr no=sg case=3 coarse=FV
# case=g gender=n no=sg coarse=Noun
# case=i gender=m no=sg coarse=Noun
# tense=pr no=sg case=1 coarse=FV
# Value of out of voc tag  1
# successful

# %% [markdown]
# ### Variation I

# %%
import re 
x = "pr. [1] ac. sg. 3"
re.sub("([\(\[]).*?([\)\]])", "\g<1>\g<2>", x).replace('[] ','')
#
# Out:
# 'pr. ac. sg. 3'

# %% [markdown]
# ### Build embedding dictionary

# %%
tag_file_name = '../data/san_tags'
files = ['ud_pos_ner_dp_dev_san','ud_pos_ner_dp_train_san','ud_pos_ner_dp_test_san']
writer = open('../models/Dep_san/'+'embedding.dict','w')
for input_file_name in files:
    data = open('../data/'+input_file_name).readlines()
    for line in data:
        if line == '\n':
            continue
        splits = line.strip().split('\t')

        word = model.get_word_vector(splits[1]);
        feature = ''
        i=0
        for v in word:
            feature = feature+' '+'F'+str(i)+':'+str(v)
            i+=1
        embedding = splits[1]+"%s"%feature;
     
        writer.write('%s\n' % (embedding))

writer.close()
print('successful')
# Out:
# successful

# %% [markdown]
# ### Create dict of MA because space is creating problem
# So change all tags to integer mapping

# %%
i=0
tag_dict = dict()
for tag in tag_set:
    tag_dict[tag] = i
    i = i+1

# %% [markdown]
# ### Modify evaluate script:

# %%
#!/usr/bin/env python
# evaluation script modified from redshift parser

import os
import sys
from collections import defaultdict

def pc(num, den):
    return (num / float(den+1e-100)) * 100

def fmt_acc(label, n, l_corr, u_corr, total_errs):
    l_pc = pc(l_corr, n)
    u_pc = pc(u_corr, n)
    err_pc = pc(n - l_corr, total_errs)
    return '%s\t%d\t%.3f\t%.3f\t%.3f' % (label, n, l_pc, u_pc, err_pc)


def gen_toks(loc):
    sent_strs = open(str(loc)).read().strip().split('\n\n')
    token = None
    i = 0
    for sent_str in sent_strs:
        # print(sent_str)
        tokens = [Token(i, tok_str.split()) for i, tok_str in enumerate(sent_str.split('\n'))]
        for token in tokens:
            yield sent_str, token

def gen_note_toks(loc):
    sent_strs = open(str(loc)).read().strip().split('\n\n')
    token = None
    i = 0
    for sent_str in sent_strs:
        # print(sent_str)
        tokens = [note_Token(i, tok_str.split('\t')) for i, tok_str in enumerate(sent_str.split('\n'))]
        for token in tokens:
            yield sent_str, token

class note_Token(object):
    def __init__(self, id_, attrs):
        self.id = id_
        self.label = attrs[-1]
        if self.label.lower() == 'root':
            self.label = 'ROOT'
        try:
            head = int(attrs[-2])
        except:
            try:
                self.label = 'P'
                head = int(attrs[-1])
            except:
                print attrs
                raise
        self.head = head
        self.pos = attrs[2]
        self.word = attrs[1]
        self.dir = 'R' if head >= 0 and head < self.id else 'L'
        
class Token(object):
    def __init__(self, id_, attrs):
        self.id = id_
        # CoNLL format
        if len(attrs) == 10:
            new_attrs = [str(int(attrs[0]) - 1)]
            new_attrs.append(attrs[1])
            new_attrs.append(attrs[3])
            new_attrs.append(str(int(attrs[-4]) - 1))
            new_attrs.append(attrs[-3])
            attrs = new_attrs
        self.label = attrs[-1]
        if self.label.lower() == 'root':
            self.label = 'ROOT'
        try:
            head = int(attrs[-2])
        except:
            try:
                self.label = 'P'
                head = int(attrs[-1])
            except:
                print attrs
                raise
        attrs.pop()
        attrs.pop()
        self.head = head
        self.pos = attrs.pop()
        self.word = attrs.pop()
        self.dir = 'R' if head >= 0 and head < self.id else 'L'

test_loc = 'Dep_san/dep.test.parse'
gold_loc = 'sanskrit_treebank/ud_pos_ner_dp_dev_san'
n_by_label = defaultdict(lambda: defaultdict(int))
u_by_label = defaultdict(lambda: defaultdict(int))
l_by_label = defaultdict(lambda: defaultdict(int))
N = 0
u_nc = 0
l_nc = 0
for (sst, t), (ss, g) in zip(gen_toks(test_loc), gen_note_toks(gold_loc)):
#     not eval_punct and 
    if g.word in ",.-;:'\"!?`{}()[]":
        continue
    prev_g = g
    prev_t = t
    u_c = g.head == t.head
    l_c = u_c and g.label.lower() == t.label.lower()
    N += 1
    l_nc += l_c
    u_nc += u_c
    n_by_label[g.dir][g.label] += 1
    u_by_label[g.dir][g.label] += u_c
    l_by_label[g.dir][g.label] += l_c
n_l_err = N - l_nc
for D in ['L', 'R']:
    n_other = 0
    l_other = 0
    u_other = 0
    for label, n in sorted(n_by_label[D].items(), key=lambda i: i[1], reverse=True):
        if n == 0:
            continue
        elif n < 100:
            n_other += n
            l_other += l_by_label[D][label]
            u_other += u_by_label[D][label]
        else:
            l_corr = l_by_label[D][label]
            u_corr = u_by_label[D][label]
print 'U: %.3f' % pc(u_nc, N)
print 'L: %.3f' % pc(l_nc, N)
# Out:
# U: 68.517
# L: 49.289

# %%
r = '6 2 6:karwa|w aham |p nom. sg. *'
r.split()
# Out:
# ['6', '2', '6:karwa|w', 'aham', '|p', 'nom.', 'sg.', '*']
